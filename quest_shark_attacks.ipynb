# %%
# Download the dataset and import it into Python
import xlrd
import pandas as pd
shark_attacks_df = pd.read_excel('GSAF5.xls')
shark_attacks_df.head()


# shark_attacks_df.rename(columns='Species':'species')
shark_attacks_df.columns

#rename to lower case and add _
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Unnamed: 11', 'Time', 'Species ',
#        'Source', 'pdf', 'href formula', 'href', 'Case Number', 'Case Number.1',
#        'original order', 'Unnamed: 21', 'Unnamed: 22'],
#       dtype='object')

# %%
# Cleaning DataFrame
#Chose the columns we will be working with
shark_attacks_df = shark_attacks_df[['Date', 'Year', 'Type', 'Country', 'State', 'Location','Activity','Sex', 'Age', 'Injury','Time','Species ']] 
shark_attacks_df

#Drop rows with year < 2010
# Out:
#              Date    Year        Type    Country             State  \
# 0     14 Feb-2024  2024.0  Unprovoked      INDIA       Maharashtra
# 1     04-Feb-2024  2024.0    Provoked   TRINIDAD               NaN
# 2     29 Jan-2024  2024.0  Unprovoked  AUSTRALIA  New  South Wales
# 3     15 Jan-2024  2024.0  Unprovoked    BAHAMAS   Paradise Island
# 4     09-Jan-2024  2024.0  Unprovoked  AUSTRALIA   South Australia
# ...           ...     ...         ...        ...               ...
# 6960          NaN     NaN         NaN        NaN               NaN
# 6961          NaN     NaN         NaN        NaN               NaN
# 6962          NaN     NaN         NaN        NaN               NaN
# 6963          NaN     NaN         NaN        NaN               NaN
# 6964          NaN     NaN         NaN        NaN               NaN
#
#                               Location      Activity  Sex  Age  \
# 0     Vaitarna River, Palghar District       Fishing    M   32
# 1                                  NaN  Spearfishing    M  NaN
# 2         Elizabeth Bay, Sydney Harbor      Swimming    F   29
# 3               Paradise Island Resort      Swimming    M   10
# 4              Walkers Beach, Elliston       Surfing    M   64
# ...                                ...           ...  ...  ...
# 6960                               NaN           NaN  NaN  NaN
# 6961                               NaN           NaN  NaN  NaN
# 6962                               NaN           NaN  NaN  NaN
# 6963                               NaN           NaN  NaN  NaN
# 6964                               NaN           NaN  NaN  NaN
#
#                               Injury   Time             Species
# 0     Calf of lower left leg injured    NaN       Bull shark, 7'
# 1                    Shoulder bitten  06h30  Blacktip reef shark
# 2                   Right leg bitten  20h00           Bull shark
# 3                 Right leg injured   16h00                  NaN
# 4                         Leg bitten  13h00          White shark
# ...                              ...    ...                  ...
# 6960                             NaN    NaN                  NaN
# 6961                             NaN    NaN                  NaN
# 6962                             NaN    NaN                  NaN
# 6963                             NaN    NaN                  NaN
# 6964                             NaN    NaN                  NaN
#
# [6965 rows x 12 columns]

# %%
import poor_bruce as pb
# clean columns titles --> remove spaces & lower cases
shark_attacks_df=pb.clean_columns_titles(shark_attacks_df)
# drop the null value rows
shark_attacks_df=pb.drop_null_values(shark_attacks_df)
display(shark_attacks_df.head(20))
# Out:
#             date    year          type       country                   state  \
# 0    14 Feb-2024  2024.0    Unprovoked         INDIA             Maharashtra
# 1    04-Feb-2024  2024.0      Provoked      TRINIDAD                     NaN
# 2    29 Jan-2024  2024.0    Unprovoked     AUSTRALIA        New  South Wales
# 3    15 Jan-2024  2024.0    Unprovoked       BAHAMAS         Paradise Island
# 4    09-Jan-2024  2024.0    Unprovoked     AUSTRALIA         South Australia
# 5    05-Jan-2024  2024.0      Provoked  SOUTH AFRICA   Eastern Cape Province
# 6    30 Dec-2023  2023.0    Unprovoked           USA                  Hawaii
# 7    29 Dec-2023  2023.0    Unprovoked        MEXICO                  Sonora
# 8    28 Dec-2023  2023.0    Unprovoked     AUSTRALIA         South Australia
# 9    25 Dec-2023  2023.0    Unprovoked     AUSTRALIA         New South Wales
# 10   24-Dec-2023  2023.0    Unprovoked     AUSTRALIA       Western Australia
# 11   18 Dec-2023  2023.0    Unprovoked   NEW ZEALAND            South Island
# 12  14  Dec-2023  2023.0  Questionable        MEXICO                Guerrero
# 13  14  Dec-2023  2023.0  Questionable        MEXICO                Guerrero
# 14   08 Dec-2023  2023.0    Unprovoked     AUSTRALIA              Queensland
# 15   04 Dec-2023  2023.0    Unprovoked       BAHAMAS  New Providence   Isoad
# 16   02 Dec-2023  2023.0    Unprovoked        MEXICO                 Jalisco
# 17   30 Nov-2023  2023.0    Unprovoked     AUSTRALIA              Queensland
# 18   21 Nov-2023  2023.0    Unprovoked       BAHAMAS    Grand  Bahama Island
# 19   10 Nov-2023  2023.0    Unprovoked     AUSTRALIA         South Australia
#
#                               location         activity sex  age  \
# 0     Vaitarna River, Palghar District          Fishing   M   32
# 1                                  NaN     Spearfishing   M  NaN
# 2         Elizabeth Bay, Sydney Harbor         Swimming   F   29
# 3               Paradise Island Resort         Swimming   M   10
# 4              Walkers Beach, Elliston          Surfing   M   64
# 5                        Papiesfontein          Fishing   M   62
# 6                     Baby Beach, Maui          Surfing   M   39
# 7   Tojahui Beach, Yavaros, Huatabampo      Free diving   M   22
# 8                          Ethel Beach          Surfing   M   15
# 9                              Old Bar          Surfing   M   16
# 10                        Wedge Island    Foil Boarding   M   46
# 11                            Riverton           Wading   F   21
# 12   Playa Quieta, Ixtapa, Zihuatanejo         Swimming   M   66
# 13   Playa Quieta, Ixtapa, Zihuatanejo         Swimming   F   52
# 14                               1770        Snorkeling   M   20
# 15                      Sandals Resort  Paddle boarding   F   44
# 16                San Patricio Melaque         Swimming   F   26
# 17                        Clack Island         Swimming   M   21
# 18                         Tiger Beach     Scuba diving   F   47
# 19                      Port Noarlunga      Free diving   F   32
#
#                                                injury           time  \
# 0                      Calf of lower left leg injured            NaN
# 1                                     Shoulder bitten          06h30
# 2                                    Right leg bitten          20h00
# 3                                  Right leg injured           16h00
# 4                                          Leg bitten          13h00
# 5   Provoked incident. Lacerations and puncture wo...            NaN
# 6                                               FATAL          11h12
# 7                                               FATAL          13h00
# 8                                               FATAL          13h30
# 9                               Injury to right thigh          16h30
# 10                     Puncture wounds to right ankle          15h00
# 11                          Significant injury to leg          02h00
# 12                                              FATAL          09h15
# 13                           Injury to lower left leg  Early Morning
# 14                              Leg severely  injured          16h32
# 15                                              FATAL          11h00
# 16                                              FATAL        Morning
# 17                 Puncture wounds to right upper arm          11h30
# 18                                              FATAL          10h30
# 19                         Injuries to scalp and face          13h20
#
#                           species
# 0                  Bull shark, 7'
# 1             Blacktip reef shark
# 2                      Bull shark
# 3                             NaN
# 4                     White shark
# 5               Raggedtooth shark
# 6                             NaN
# 7                     White shark
# 8                White shark, 13'
# 9                             NaN
# 10                  Broze whaler?
# 11                Sevengill shark
# 12  Shark involment not confirmed
# 13  Shark involment not confirmed
# 14                            NaN
# 15                            NaN
# 16                            NaN
# 17                1.8m bull shark
# 18                            NaN
# 19                            NaN

# %%
# check null values left
shark_attacks_df.isnull().sum()
# Out:
# date           0
# year           2
# type          18
# country       50
# state        482
# location     565
# activity     585
# sex          579
# age         2993
# injury        35
# time        3525
# species     3132
# dtype: int64

# %%
# From year 2010 - present  ---NURIA



# standardise the date,year,country,
# make age group for child teen adult senior

# %%
# country  --- Ste
